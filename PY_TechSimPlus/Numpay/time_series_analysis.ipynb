# %%
import pandas as pd

# %%
data = pd.read_csv("./dataset/Reliance.csv",parse_dates=["Date "],index_col="Date ")
#parse_dates is used to convert the date from string to timestamps and indec_col is used to ake the column as index

# %%
data.shape
# Out:
# (248, 14)

# %%
data
# Out:
#          Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0   2024-08-27      EQ  3,021.00  3,026.95  2,998.90     3,025.20  3,001.00
# 1   2024-08-26      EQ  3,013.95  3,046.00  3,006.00     2,999.95  3,021.20
# 2   2024-08-23      EQ  3,007.50  3,022.65  2,996.85     2,996.25  2,996.85
# 3   2024-08-22      EQ  3,006.00  3,013.00  2,981.30     2,997.35  2,996.50
# 4   2024-08-21      EQ  2,986.50  3,015.75  2,980.00     2,991.90  2,999.00
# ..         ...     ...       ...       ...       ...          ...       ...
# 243 2023-09-01      EQ  2,406.55  2,425.65  2,401.65     2,407.00  2,411.40
# 244 2023-08-31      EQ  2,423.00  2,425.00  2,399.90     2,418.05  2,408.00
# 245 2023-08-30      EQ  2,432.00  2,443.00  2,415.00     2,420.35  2,419.40
# 246 2023-08-29      EQ  2,452.05  2,453.45  2,408.15     2,443.75  2,422.00
# 247 2023-08-28      EQ  2,472.00  2,484.00  2,431.10     2,468.35  2,436.95
#
# ...

# %%
data.columns
# Out:
# Index(['Date ', 'series ', 'OPEN ', 'HIGH ', 'LOW ', 'PREV. CLOSE ', 'ltp ',
#        'close ', 'vwap ', '52W H ', '52W L ', 'VOLUME ', 'VALUE ',
#        'No of trades '],
#       dtype='object')

# %%
data['Date ']
# Out:
# 0     2024-08-27
# 1     2024-08-26
# 2     2024-08-23
# 3     2024-08-22
# 4     2024-08-21
#          ...
# 243   2023-09-01
# 244   2023-08-31
# 245   2023-08-30
# 246   2023-08-29
# 247   2023-08-28
# Name: Date , Length: 248, dtype: datetime64[ns]

# %%
data.iloc[2]['Date ']
data['Date '][2]
# Out:
# Timestamp('2024-08-23 00:00:00')

# %%
type(data['Date '][2])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
data.iloc[1:4,0:3]
# Out:
#        Date  series      OPEN
# 1 2024-08-26      EQ  3,013.95
# 2 2024-08-23      EQ  3,007.50
# 3 2024-08-22      EQ  3,006.00

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 248 entries, 0 to 247
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           248 non-null    datetime64[ns]
#  1   series         248 non-null    object
#  2   OPEN           248 non-null    object
#  3   HIGH           248 non-null    object
#  4   LOW            248 non-null    object
#  5   PREV. CLOSE    248 non-null    object
#  6   ltp            248 non-null    object
#  7   close          248 non-null    object
#  8   vwap           248 non-null    object
#  9   52W H          248 non-null    object
#  10  52W L          248 non-null    object
#  11  VOLUME         248 non-null    object
#  12  VALUE          248 non-null    object
#  13  No of trades   248 non-null    object
# dtypes: datetime64[ns](1), object(13)
# memory usage: 27.3+ KB

# %%
data.iloc[0]
# Out:
# Date             2024-08-27 00:00:00
# series                            EQ
# OPEN                        3,021.00
# HIGH                        3,026.95
# LOW                         2,998.90
# PREV. CLOSE                 3,025.20
# ltp                         3,001.00
# close                       3,000.90
# vwap                        3,008.12
# 52W H                       3,217.60
# 52W L                       2,220.30
# VOLUME                     31,25,578
# VALUE              9,40,21,08,149.05
# No of trades                1,01,024
# Name: 0, dtype: object

# %%
data.head()
# Out:
#            series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# Date
# 2024-08-27      EQ  3,021.00  3,026.95  2,998.90     3,025.20  3,001.00
# 2024-08-26      EQ  3,013.95  3,046.00  3,006.00     2,999.95  3,021.20
# 2024-08-23      EQ  3,007.50  3,022.65  2,996.85     2,996.25  2,996.85
# 2024-08-22      EQ  3,006.00  3,013.00  2,981.30     2,997.35  2,996.50
# 2024-08-21      EQ  2,986.50  3,015.75  2,980.00     2,991.90  2,999.00
#
#               close      vwap     52W H     52W L     VOLUME   \
# Date
# 2024-08-27  3,000.90  3,008.12  3,217.60  2,220.30  31,25,578
# 2024-08-26  3,025.20  3,028.80  3,217.60  2,220.30  44,08,057
# 2024-08-23  2,999.95  3,007.21  3,217.60  2,220.30  46,24,827
# 2024-08-22  2,996.25  2,994.88  3,217.60  2,220.30  52,22,891
# 2024-08-21  2,997.35  3,001.42  3,217.60  2,220.30  38,84,998
#
#                         VALUE  No of trades
# Date
# 2024-08-27   9,40,21,08,149.05      1,01,024
# 2024-08-26  13,35,11,14,538.35      2,37,540
# ...

# %%
data.loc["2024-08-23"]
# Out:
# series                           EQ
# OPEN                       3,007.50
# HIGH                       3,022.65
# LOW                        2,996.85
# PREV. CLOSE                2,996.25
# ltp                        2,996.85
# close                      2,999.95
# vwap                       3,007.21
# 52W H                      3,217.60
# 52W L                      2,220.30
# VOLUME                    46,24,827
# VALUE            13,90,78,42,193.30
# No of trades               1,68,002
# Name: 2024-08-23 00:00:00, dtype: object

# %%
data.loc[["2024-08-26","2024-08-23"]]
# Out:
#            series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# Date
# 2024-08-26      EQ  3,013.95  3,046.00  3,006.00     2,999.95  3,021.20
# 2024-08-23      EQ  3,007.50  3,022.65  2,996.85     2,996.25  2,996.85
#
#               close      vwap     52W H     52W L     VOLUME   \
# Date
# 2024-08-26  3,025.20  3,028.80  3,217.60  2,220.30  44,08,057
# 2024-08-23  2,999.95  3,007.21  3,217.60  2,220.30  46,24,827
#
#                         VALUE  No of trades
# Date
# 2024-08-26  13,35,11,14,538.35      2,37,540
# 2024-08-23  13,90,78,42,193.30      1,68,002

# %%
data["close "]
# Out:
# Date
# 2024-08-27    3,000.90
# 2024-08-26    3,025.20
# 2024-08-23    2,999.95
# 2024-08-22    2,996.25
# 2024-08-21    2,997.35
#                 ...
# 2023-09-01    2,412.65
# 2023-08-31    2,407.00
# 2023-08-30    2,418.05
# 2023-08-29    2,420.35
# 2023-08-28    2,443.75
# Name: close , Length: 248, dtype: object

# %%
price = "3,000.90".split(",")
float("".join(price))
# Out:
# 3000.9

# %%
def formate_price(price):
    price = price.split(",")
    price_in_float = float("".join(price))
    return price_in_float

# %%
data["close "]=data["close "].apply(formate_price)

# %%
data["close "].plot()
# Out:
# <Axes: xlabel='Date '>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 248 entries, 2024-08-27 to 2023-08-28
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   series         248 non-null    object
#  1   OPEN           248 non-null    object
#  2   HIGH           248 non-null    object
#  3   LOW            248 non-null    object
#  4   PREV. CLOSE    248 non-null    object
#  5   ltp            248 non-null    object
#  6   close          248 non-null    float64
#  7   vwap           248 non-null    object
#  8   52W H          248 non-null    object
#  9   52W L          248 non-null    object
#  10  VOLUME         248 non-null    object
#  11  VALUE          248 non-null    object
#  12  No of trades   248 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 35.2+ KB

# %%
data["close "].resample("M").mean()
# Out:
# C:\Users\praty\AppData\Local\Temp\ipykernel_17104\2833856587.py:1: FutureWarning: 'M' is deprecated and will be removed in a future version, please use 'ME' instead.
#   data["close "].resample("M").mean()
# Date
# 2023-08-31    2422.287500
# 2023-09-30    2405.040000
# 2023-10-31    2307.860000
# 2023-11-30    2350.371429
# 2023-12-31    2499.625000
# 2024-01-31    2696.781818
# 2024-02-29    2924.923810
# 2024-03-31    2929.618421
# 2024-04-30    2936.162500
# 2024-05-31    2868.920455
# 2024-06-30    2940.765789
# 2024-07-31    3101.168182
# 2024-08-31    2962.747222
# Freq: ME, Name: close , dtype: float64

# %%
rng = pd.date_range(start = "1/1/2024", end = "8/29/2024", freq="B")
rng
#B = Business days
#D = all days
#W = Weekend
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-08', '2024-01-09', '2024-01-10',
#                '2024-01-11', '2024-01-12',
#                ...
#                '2024-08-16', '2024-08-19', '2024-08-20', '2024-08-21',
#                '2024-08-22', '2024-08-23', '2024-08-26', '2024-08-27',
#                '2024-08-28', '2024-08-29'],
#               dtype='datetime64[ns]', length=174, freq='B')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
daily_dates = pd.date_range(start = "1/1/2024", end = "8/29/2024", freq="D",inclusive="right")

# %%
daily_dates.difference(rng)   #gives saturday sunday dates
# Out:
# DatetimeIndex(['2024-01-06', '2024-01-07', '2024-01-13', '2024-01-14',
#                '2024-01-20', '2024-01-21', '2024-01-27', '2024-01-28',
#                '2024-02-03', '2024-02-04', '2024-02-10', '2024-02-11',
#                '2024-02-17', '2024-02-18', '2024-02-24', '2024-02-25',
#                '2024-03-02', '2024-03-03', '2024-03-09', '2024-03-10',
#                '2024-03-16', '2024-03-17', '2024-03-23', '2024-03-24',
#                '2024-03-30', '2024-03-31', '2024-04-06', '2024-04-07',
#                '2024-04-13', '2024-04-14', '2024-04-20', '2024-04-21',
#                '2024-04-27', '2024-04-28', '2024-05-04', '2024-05-05',
#                '2024-05-11', '2024-05-12', '2024-05-18', '2024-05-19',
#                '2024-05-25', '2024-05-26', '2024-06-01', '2024-06-02',
#                '2024-06-08', '2024-06-09', '2024-06-15', '2024-06-16',
#                '2024-06-22', '2024-06-23', '2024-06-29', '2024-06-30',
# ...

# %%
data2 = pd.read_csv("./dataset/Reliance.csv")

# %%
data2
# Out:
#            Date  series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 0    27-Aug-2024      EQ  3,021.00  3,026.95  2,998.90     3,025.20  3,001.00
# 1    26-Aug-2024      EQ  3,013.95  3,046.00  3,006.00     2,999.95  3,021.20
# 2    23-Aug-2024      EQ  3,007.50  3,022.65  2,996.85     2,996.25  2,996.85
# 3    22-Aug-2024      EQ  3,006.00  3,013.00  2,981.30     2,997.35  2,996.50
# 4    21-Aug-2024      EQ  2,986.50  3,015.75  2,980.00     2,991.90  2,999.00
# ..           ...     ...       ...       ...       ...          ...       ...
# 243  01-Sep-2023      EQ  2,406.55  2,425.65  2,401.65     2,407.00  2,411.40
# 244  31-Aug-2023      EQ  2,423.00  2,425.00  2,399.90     2,418.05  2,408.00
# 245  30-Aug-2023      EQ  2,432.00  2,443.00  2,415.00     2,420.35  2,419.40
# 246  29-Aug-2023      EQ  2,452.05  2,453.45  2,408.15     2,443.75  2,422.00
# 247  28-Aug-2023      EQ  2,472.00  2,484.00  2,431.10     2,468.35  2,436.95
#
# ...

# %%
data2.drop("Date ",axis=1,inplace=True)
data2
# Out:
#     series      OPEN      HIGH       LOW  PREV. CLOSE       ltp     close   \
# 0        EQ  3,021.00  3,026.95  2,998.90     3,025.20  3,001.00  3,000.90
# 1        EQ  3,013.95  3,046.00  3,006.00     2,999.95  3,021.20  3,025.20
# 2        EQ  3,007.50  3,022.65  2,996.85     2,996.25  2,996.85  2,999.95
# 3        EQ  3,006.00  3,013.00  2,981.30     2,997.35  2,996.50  2,996.25
# 4        EQ  2,986.50  3,015.75  2,980.00     2,991.90  2,999.00  2,997.35
# ..      ...       ...       ...       ...          ...       ...       ...
# 243      EQ  2,406.55  2,425.65  2,401.65     2,407.00  2,411.40  2,412.65
# 244      EQ  2,423.00  2,425.00  2,399.90     2,418.05  2,408.00  2,407.00
# 245      EQ  2,432.00  2,443.00  2,415.00     2,420.35  2,419.40  2,418.05
# 246      EQ  2,452.05  2,453.45  2,408.15     2,443.75  2,422.00  2,420.35
# 247      EQ  2,472.00  2,484.00  2,431.10     2,468.35  2,436.95  2,443.75
#
# ...

# %%
data2.shape
# Out:
# (248, 13)

# %%
dates = pd.date_range(start = "2024-01-01",periods=248)
dates
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10',
#                ...
#                '2024-08-26', '2024-08-27', '2024-08-28', '2024-08-29',
#                '2024-08-30', '2024-08-31', '2024-09-01', '2024-09-02',
#                '2024-09-03', '2024-09-04'],
#               dtype='datetime64[ns]', length=248, freq='D')

# %%
data2.set_index(dates)
# Out:
#            series      OPEN      HIGH       LOW  PREV. CLOSE       ltp   \
# 2024-01-01      EQ  3,021.00  3,026.95  2,998.90     3,025.20  3,001.00
# 2024-01-02      EQ  3,013.95  3,046.00  3,006.00     2,999.95  3,021.20
# 2024-01-03      EQ  3,007.50  3,022.65  2,996.85     2,996.25  2,996.85
# 2024-01-04      EQ  3,006.00  3,013.00  2,981.30     2,997.35  2,996.50
# 2024-01-05      EQ  2,986.50  3,015.75  2,980.00     2,991.90  2,999.00
# ...            ...       ...       ...       ...          ...       ...
# 2024-08-31      EQ  2,406.55  2,425.65  2,401.65     2,407.00  2,411.40
# 2024-09-01      EQ  2,423.00  2,425.00  2,399.90     2,418.05  2,408.00
# 2024-09-02      EQ  2,432.00  2,443.00  2,415.00     2,420.35  2,419.40
# 2024-09-03      EQ  2,452.05  2,453.45  2,408.15     2,443.75  2,422.00
# 2024-09-04      EQ  2,472.00  2,484.00  2,431.10     2,468.35  2,436.95
#
#               close      vwap     52W H     52W L       VOLUME   \
# ...

# %% [markdown]
# to_datetime

# %%
dates = ['2024-01-05','jan 5,2024','01/05/2024','2024.01.05','2024/01/05']

# %%
pd.to_datetime(dates,errors="coerce")
# Out:
# DatetimeIndex(['2024-01-05', 'NaT', 'NaT', 'NaT', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
pd.to_datetime('jan 5,2024')
# Out:
# Timestamp('2024-01-05 00:00:00')

# %%
pd.to_datetime('01/05/2024')
# Out:
# Timestamp('2024-01-05 00:00:00')

# %%
pd.to_datetime('2024$01$05',format = "%Y$%M$%d")
# Out:
# Timestamp('2024-01-05 00:01:00')

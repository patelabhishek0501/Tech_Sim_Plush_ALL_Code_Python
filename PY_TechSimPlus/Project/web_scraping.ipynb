# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
data = [
        ["Noise Watch","4.1 out of 5 star","3000","1500"],
        ["Firebolt Watch","4.1 out of 5 star","3000","1500"]
        ]
df = pd.DataFrame(data,columns = ["Product Name","Rating","Review Count","Price"])

# %%
df
# Out:
#      Product Name             Rating Review Count Price
# 0     Noise Watch  4.1 out of 5 star         3000  1500
# 1  Firebolt Watch  4.1 out of 5 star         3000  1500

# %%
url = "https://www.amazon.in/gp/bestsellers/watches/ref=zg_bs_nav_watches_0"
response = requests.get(url)
content = response.content
soup = BeautifulSoup(content)
heading_html = soup.find('h1',attrs={"class": "a-size-large a-spacing-medium a-text-bold"})
heading_html.get_text()

product_cards = soup.find_all("div",attrs={"id": "gridItemRoot"})

def get_product_details(product_card):
  name_html = product_card.find("a",attrs={"class": "a-link-normal"})
  if name_html:
    image = name_html.find('img')
    name = image.get('alt')
  else:
    name = ""

  rating_html = product_card.find('i',attrs={"class":"a-icon a-icon-star-small a-star-small-4 aok-align-top"})
  if rating_html:
     rating = rating_html.get_text()
  else:
    rating = ""


  review_html = product_card.find('span',attrs={"class": "a-size-small"})
  if review_html:
     review_count = review_html.get_text()
  else:
    review_count = ""

  aRows_last_div = product_card.find_all('div',attrs={"class": "a-row"})[-1]

  price_html = aRows_last_div.find("span",{"class": "p13n-sc-price"})

  if price_html:
      price = price_html.get_text()

  else:
    price = ""




  return [name,rating,review_count,price ]

# %%
data = []
for product_card in product_cards:
  detail = get_product_details(product_card)
  data.append(detail)

# %%
data
# Out:
# [['Noise Twist Round dial Smart Watch with Bluetooth Calling, 1.38" TFT Display, up-to 7 Days Battery, 100+ Watch Faces, IP68, H',
#   '4.1 out of 5 stars',
#   '25,065',
#   '₹1,399.00'],
#  ['Noise Pulse Go Buzz Smart Watch with Advanced Bluetooth Calling, 1.69" TFT Display, SpO2, 100 Sports Mode with Auto Detection',
#   '4.1 out of 5 stars',
#   '40,797',
#   '₹1,299.00'],
#  ['Fastrack New Limitless X2 Smartwatch|1.91" UltraVU with Rotating Crown|60 Hz Refresh Rate|Advanced Chipset|SingleSync BT Call',
#   '3.9 out of 5 stars',
#   '8,594',
#   '₹1,499.00'],
#  ['Noise ColorFit Pulse Grand Smart Watch with 1.69"(4.29cm) HD Display, 60 Sports Modes, 150 Watch Faces, Fast Charge, Spo2, St',
#   '4.0 out of 5 stars',
#   '21,654',
#   '₹1,099.00'],
#  ['boAt Wave Lite Smart Watch w/ 1.69" (4.2 cm) HD Display, Sleek Metal Body, HR & SpO2 Level Monitor, 140+ Watch Faces, Activit',
#   '3.9 out of 5 stars',
#   '70,092',
#   '₹999.00'],
#  ['Fire-Boltt Phoenix Ultra Luxury Stainless Steel, Bluetooth Calling Smartwatch, AI Voice Assistant, Metal Body with 120+ Sport',
#   '4.1 out of 5 stars',
#   '72,755',
#   '₹1,799.00'],
#  ['Casio Vintage A158WA-1DF Black Digital Dial Silver Stainless Steel Band D011',
#   '',
#   '43,322',
#   '₹1,695.00'],
#  ['Fire-Boltt Ninja Call Pro Plus 46.48mm (1.83 inch) Smart Watch with Bluetooth Calling, AI Voice Assistance, 100 Sports Modes ',
#   '4.1 out of 5 stars',
#   '69,394',
#   '₹1,399.00'],
#  ['TIMEWEAR Analog Day Date Functioning Stainless Steel Chain Watch for Men',
#   '3.8 out of 5 stars',
#   '13,102',
#   '₹319.00'],
#  ['Sounce Silicone 22mm Replacement Watch Strap with Metal Buckle Compatible with Boat Xtend, Boat Xtend Pro, Noise Colorfit Pul',
#   '4.2 out of 5 stars',
#   '3,015',
#   '₹299.00'],
#  ['SPIKY 3D Cartoon Kids Analog Watch with LED Luminous 7 Multicolour Glowing Disco Light | Unbreakable Silicone Strap | Childre',
#   '4.0 out of 5 stars',
#   '2,020',
#   '₹494.00'],
#  ['Matrix Antique 2.0 Day & Date Softest Silicone Strap Analog Watch for Men & Boys',
#   '4.1 out of 5 stars',
#   '1,396',
#   '₹318.00'],
#  ['Fastrack Analog Unisex-Adult Watch',
#   '4.2 out of 5 stars',
#   '12,867',
#   '₹815.00'],
#  ["LEDO Men's and Women's Watch Box Holder Organizer Case In 12 Slots of watches In PU Leather with Black & Gray",
#   '',
#   '1,216',
#   '₹998.00'],
#  ['Acnos 6 Colours Luminous LED Display Fashionable Children Kids Digital Watches Waterproof Sports Square Electronic Led Watch ',
#   '3.9 out of 5 stars',
#   '634',
#   '₹280.00'],
#  ["TIMEX Analog Men's Watch (Dial Colored Strap)",
#   '4.1 out of 5 stars',
#   '21,603',
#   '₹957.00'],
#  ['LOUIS DEVIN Silicone Strap Analog Wrist Watch for Men (Black/Blue/Red) | LD-BK054',
#   '4.0 out of 5 stars',
#   '3,421',
#   '₹369.00'],
#  ['Shocknshop Digital Sports Multi Functional Black Dial Watch for Mens Boys -315RED',
#   '3.9 out of 5 stars',
#   '8,718',
#   '₹284.00'],
#  ['Acnos® Premium Brand - A Digital Watch Shockproof Multi-Functional Automatic 5 Color Army Strap Waterproof Digital Sports Wat',
#   '4.1 out of 5 stars',
#   '1,680',
#   '₹284.00'],
#  ['Acnos® Premium Brand Digital 4 Colours Square Dial Unisex Wrist Watch for Men Women Pack of 1 (WR)',
#   '3.8 out of 5 stars',
#   '1,405',
#   '₹280.00'],
#  ["SKMEI Men's Watch New Wheels Rolling Creative Fashion Che Youhui League Fans Butterfly Double Snap Gift Wristwatch - 1990",
#   '4.2 out of 5 stars',
#   '1,027',
#   '₹1,798.00'],
#  ['Samsung Galaxy Fit3 (Gray), 40mm AMOLED Display with Aluminium Body, Comprehensive Fitness and Health Tracking, Upto 13-Day B',
#   '3.9 out of 5 stars',
#   '795',
#   '₹4,499.00'],
#  ['Carlington Analog-Digital Sports Watch: Chronograph, Dual Time, Alarm, Stopwatch, Water-Resistant, Shock-Resistant, Back Ligh',
#   '4.0 out of 5 stars',
#   '298',
#   '₹1,199.00'],
#  ['Fastrack Fastfit Quartz Analog Grey Dial Silicone Strap Unisex Watch-NS68011PP08',
#   '4.2 out of 5 stars',
#   '918',
#   '₹895.00'],
#  ["STYLEDOSE Women Analogue Wrist Watches for Women's & Girls&Miss&Ladies Diamond Studded Dial RoseGold Colored Stylish Bracelet",
#   '',
#   '114',
#   '₹399.00'],
#  ["Titan Karishma Analog Black Dial Men's Watch NM1639SM02/NN1639SM02",
#   '',
#   '1,927',
#   '₹1,995.00'],
#  ['Casio Vintage A168WA-1WDF Black Digital Dial Silver Stainless Steel Band D131',
#   '',
#   '3,139',
#   '₹2,695.00'],
#  ["LEDO Men's and Women's Watch Box Holder Organizer Case In 12 Slots of watches In PU Leather with Royal Black color",
#   '',
#   '3,735',
#   '₹898.00'],
#  ['Titan Smart 3 Premium Smart Watch|1.96" Super AMOLED Display with 410x502 Pixel Resolution|SingleSync BT Calling|NitroFast Ch',
#   '3.8 out of 5 stars',
#   '1,228',
#   '₹4,995.00'],
#  ['Matrix Kids Edition Spiderman/Barbie/Ben 10 / Marvel Avengers Digital Watch with 24 Image Projection (Boys & Girls)',
#   '3.8 out of 5 stars',
#   '286',
#   '₹229.00'],
#  ['Fossil Decker Brown Watch', '4.2 out of 5 stars', '5,658', '₹5,097.00'],
#  ["Acnos Premium Analogue Women's Rose-Gold Magnet Watch With Rosegold Bracelet With Gift Box - Metal",
#   '4.1 out of 5 stars',
#   '1,677',
#   '₹280.00'],
#  ['Fastrack Dezire FX1 Luxury Metal Smartwatch with 1.38” UltraVU HD Display with Bright Pixel Resolution|60 Hz Fluid Display|Fu',
#   '3.9 out of 5 stars',
#   '89',
#   '₹2,499.00'],
#  ['CRESTELLO Silicone Strap Analog Wrist Watch for Women (Black/Blue/Green/Brown) | CR-Ck137',
#   '4.1 out of 5 stars',
#   '275',
#   '₹299.00'],
#  ['ADAMO Digital 24 Images Projector Watch for Kids Boys Rubber Material Watch, Diwali Gift, Birthday Return Gift, Best Digital ',
#   '',
#   '782',
#   '₹214.00'],
#  ["ZENWOOD Men's Women's, 12-Slot Watch Case with Large Glass Lid, Removable Watch Pillows, Watch Box Organizer, Gift for Loved ",
#   '',
#   '31',
#   '₹838.00'],
#  ['Fastrack Limitless Fs2 with 1.91" Super Ultravu Display|Bt Calling|Advanced ATS Chipset|Functional Crown|320X385 Pixel Resolu',
#   '4.0 out of 5 stars',
#   '4,926',
#   '₹1,999.00'],
#  ["SKMEI Men's Watch New Wheels Rolling Creative Fashion Che Youhui League Fans Butterfly Double Snap Gift Wristwatch - 1787",
#   '4.2 out of 5 stars',
#   '686',
#   '₹1,798.00'],
#  ['Leather World Engineered Wood Watch Box Holder Organizer Case In 6 Slots Of Watches For Men And Women With Transparent Displa',
#   '',
#   '1,179',
#   '₹699.00'],
#  ['Fire-Boltt Dapper’s 54.61 mm (2.15 inch) IPS Big Screen, GPS Tracking, Compass, Wireless Charging, Bluetooth Calling, 105 Spo',
#   '3.9 out of 5 stars',
#   '43,506',
#   '₹1,999.00'],
#  ['LOUIS DEVIN Rose Gold Plated Mesh Chain Analog Wrist Watch for Women (Blue/Green/Brown/Black Dial) | LD-RG173',
#   '4.0 out of 5 stars',
#   '488',
#   '₹349.00'],
#  ['LOUIS DEVIN Rose Gold Plated Mesh Chain Analog Wrist Watch for Women (Black/Blue/Rose Gold Dial) | RG162',
#   '4.0 out of 5 stars',
#   '588',
#   '₹349.00'],
#  ["Matrix Day & Date Analog Men's Watch", '', '4,291', '₹299.00'],
#  ['Matrix Kids Edition Spiderman/Frozen/Ben 10 / Hello Kitty/Marvel Avengers Digital Watch for Kids with Disco LED Lights (Boys ',
#   '3.8 out of 5 stars',
#   '1,966',
#   '₹289.00'],
#  ['Acnos® Premium White Dial Diamond Pink Analog Watch Love Heart Diamond Bracelet for Girls Best Design Butterfly Combo 3 Pack ',
#   '4.2 out of 5 stars',
# 29  Matrix Kids Edition Spiderman/Barbie/Ben 10 / ...  3.8 out of 5 stars
# 30                          Fossil Decker Brown Watch  4.2 out of 5 stars
# 31  Acnos Premium Analogue Women's Rose-Gold Magne...  4.1 out of 5 stars
# 32  Fastrack Dezire FX1 Luxury Metal Smartwatch wi...  3.9 out of 5 stars
# 33  CRESTELLO Silicone Strap Analog Wrist Watch fo...  4.1 out of 5 stars
# 34  ADAMO Digital 24 Images Projector Watch for Ki...
# 35  ZENWOOD Men's Women's, 12-Slot Watch Case with...
# 36  Fastrack Limitless Fs2 with 1.91" Super Ultrav...  4.0 out of 5 stars
# 37  SKMEI Men's Watch New Wheels Rolling Creative ...  4.2 out of 5 stars
# 38  Leather World Engineered Wood Watch Box Holder...
# 39  Fire-Boltt Dapper’s 54.61 mm (2.15 inch) IPS B...  3.9 out of 5 stars
# 40  LOUIS DEVIN Rose Gold Plated Mesh Chain Analog...  4.0 out of 5 stars
# 41  LOUIS DEVIN Rose Gold Plated Mesh Chain Analog...  4.0 out of 5 stars
# 42               Matrix Day & Date Analog Men's Watch
# 43  Matrix Kids Edition Spiderman/Frozen/Ben 10 / ...  3.8 out of 5 stars
# 44  Acnos® Premium White Dial Diamond Pink Analog ...  4.2 out of 5 stars
# 45  Joker & Witch Nebula Stainless Steel Band Anal...  3.9 out of 5 stars
# 46  SF Quartz Analog White Dial Watch for Men-NS79...  3.9 out of 5 stars
# 47  TIMEWEAR Analog New Track Number Dial Day Date...
# 48  Acnos® Premium Brand - A Watch Analogue Plain ...  4.1 out of 5 stars
# 49  Shocknshop LED Luminous Child Kids Children Cu...  4.0 out of 5 stars
#
#    Review Count      Price
# 0        25,065  ₹1,399.00
# 1        40,797  ₹1,299.00
# 2         8,594  ₹1,499.00
# 3        21,654  ₹1,099.00
# 4        70,092    ₹999.00
# 5        72,755  ₹1,799.00
# 6        43,322  ₹1,695.00
# 7        69,394  ₹1,399.00
# 8        13,102    ₹319.00
# 9         3,015    ₹299.00
# 10        2,020    ₹494.00
# 11        1,396    ₹318.00
# 12       12,867    ₹815.00
# 13        1,216    ₹998.00
# 14          634    ₹280.00
# 15       21,603    ₹957.00
# 16        3,421    ₹369.00
# 17        8,718    ₹284.00
# 18        1,680    ₹284.00
# 19        1,405    ₹280.00
# 20        1,027  ₹1,798.00
# 21          795  ₹4,499.00
# 22          298  ₹1,199.00
# 23          918    ₹895.00
# 24          114    ₹399.00
# 25        1,927  ₹1,995.00
# 26        3,139  ₹2,695.00
# 27        3,735    ₹898.00
# 28        1,228  ₹4,995.00
# 29          286    ₹229.00
# 30        5,658  ₹5,097.00
# 31        1,677    ₹280.00
# 32           89  ₹2,499.00
# 33          275    ₹299.00
# 34          782    ₹214.00
# 35           31    ₹838.00
# 36        4,926  ₹1,999.00
# 37          686  ₹1,798.00
# 38        1,179    ₹699.00
# 39       43,506  ₹1,999.00
# 40          488    ₹349.00
# 41          588    ₹349.00
# 42        4,291    ₹299.00
# 43        1,966    ₹289.00
# 44          710    ₹325.00
# 45        1,205    ₹699.00
# 46       11,343    ₹649.00
# 47        1,355    ₹329.00
# 48        1,689    ₹299.00
# 49          734    ₹369.00

# %%
df.to_csv("amazon_watches_collections.cvs")
